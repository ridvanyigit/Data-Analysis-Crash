# %% [markdown]
# <a href="https://colab.research.google.com/github/ridvanyigit/Data-Analysis-Crash/blob/main/Pandas_Crash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'apple': [3,1,4,5],
    'orange': [1,5,6,8]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    apple  orange
# 0      3       1
# 1      1       5
# 2      4       6
# 3      5       8

# %%
df['apple']
# Out:
# 0    3
# 1    1
# 2    4
# 3    5
# Name: apple, dtype: int64

# %%
type(df['apple'])
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/nba.csv', index_col='Name')
df.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/IMDB-Movie-Data.csv')
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/IMDB-Movie-Data.csv', index_col='Rank')
df.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
df.shape
# Out:
# (1000, 11)

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df1 = pd.concat([df, df], ignore_index=True)
df1.shape
# Out:
# (2000, 11)

# %%
df1.duplicated().sum()
# Out:
# 1000

# %%
df2 = df1.drop_duplicates()
df2.shape
# Out:
# (1000, 11)

# %%
df1.shape
# Out:
# (2000, 11)

# %%
df1.drop_duplicates()
df1.shape
# Out:
# (2000, 11)

# %%
df1.drop_duplicates(inplace=True)
df1.shape
# Out:
# (1000, 11)

# %% [markdown]
# #### Columns Cleanup

# %%
col = df.columns

# %%
list(col)
# Out:
# ['Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore']

# %%
len(col)
# Out:
# 11

# %%
type(list(col))
# Out:
# list

# %%
df.describe()
# Out:
#               Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean   2012.783000         113.172000     6.723200  1.698083e+05
# std       3.205962          18.810908     0.945429  1.887626e+05
# min    2006.000000          66.000000     1.900000  6.100000e+01
# 25%    2010.000000         100.000000     6.200000  3.630900e+04
# 50%    2014.000000         111.000000     6.800000  1.107990e+05
# 75%    2016.000000         123.000000     7.400000  2.399098e+05
# max    2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
col1 = ['a', 'b', 'c', 'd','e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
df.columns = col1

# %%
df.head()
# Out:
#                             a                         b  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                                       c                     d  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                       e     f    g    h  \
# Rank
# ...

# %%
df.columns = col

# %%
df.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.rename(columns={'Runtime (Minutes)': 'Runtime', 'Revenue (Millions)': 'Revenue'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
df.isnull().sum()
# Out:
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        128
# Metascore       64
# dtype: int64

# %%
df1 = df.dropna()
df1.isnull().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# Director       0
# Actors         0
# Year           0
# Runtime        0
# Rating         0
# Votes          0
# Revenue        0
# Metascore      0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 11)

# %%
df1.shape
# Out:
# (838, 11)

# %%
len(df)-len(df1)
# Out:
# 162

# %%
df3 = df.fillna(0)
df3.isnull().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# Director       0
# Actors         0
# Year           0
# Runtime        0
# Rating         0
# Votes          0
# Revenue        0
# Metascore      0
# dtype: int64

# %%
df3.shape
# Out:
# (1000, 11)

# %% [markdown]
# #### Imputation

# %%
df.isnull().sum()
# Out:
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        128
# Metascore       64
# dtype: int64

# %%
revenue = df['Revenue']

# %%
type(revenue)
# Out:
# pandas.core.series.Series

# %%
revenue.tail()
# Out:
# Rank
# 996       NaN
# 997     17.54
# 998     58.01
# 999       NaN
# 1000    19.64
# Name: Revenue, dtype: float64

# %%
revenue_mean = revenue.mean()
revenue_mean
# Out:
# 82.95637614678898

# %%
revenue.fillna(revenue_mean, inplace=True)

# %%
revenue.tail()
# Out:
# Rank
# 996     82.956376
# 997     17.540000
# 998     58.010000
# 999     82.956376
# 1000    19.640000
# Name: Revenue, dtype: float64

# %%
revenue.isnull().sum()
# Out:
# 0

# %%
df['Revenue'] = revenue

# %%
df.isnull().sum()
# Out:
# Title           0
# Genre           0
# Description     0
# Director        0
# Actors          0
# Year            0
# Runtime         0
# Rating          0
# Votes           0
# Revenue         0
# Metascore      64
# dtype: int64

# %%
metascore = df['Metascore']
metascore_mean = metascore.mean()
metascore.fillna(metascore_mean, inplace=True)
df['Metascore'] = metascore
df.isnull().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# Director       0
# Actors         0
# Year           0
# Runtime        0
# Rating         0
# Votes          0
# Revenue        0
# Metascore      0
# dtype: int64

# %%
df.describe() #it takes just numerical columns
# Out:
#               Year      Runtime       Rating         Votes      Revenue  \
# count  1000.000000  1000.000000  1000.000000  1.000000e+03  1000.000000
# mean   2012.783000   113.172000     6.723200  1.698083e+05    82.956376
# std       3.205962    18.810908     0.945429  1.887626e+05    96.412043
# min    2006.000000    66.000000     1.900000  6.100000e+01     0.000000
# 25%    2010.000000   100.000000     6.200000  3.630900e+04    17.442500
# 50%    2014.000000   111.000000     6.800000  1.107990e+05    60.375000
# 75%    2016.000000   123.000000     7.400000  2.399098e+05    99.177500
# max    2016.000000   191.000000     9.000000  1.791916e+06   936.630000
#
#          Metascore
# count  1000.000000
# mean     58.985043
# std      16.634858
# min      11.000000
# 25%      47.750000
# 50%      58.985043
# 75%      71.000000
# max     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Genre        1000 non-null   object
#  2   Description  1000 non-null   object
#  3   Director     1000 non-null   object
#  4   Actors       1000 non-null   object
#  5   Year         1000 non-null   int64
#  6   Runtime      1000 non-null   int64
#  7   Rating       1000 non-null   float64
#  8   Votes        1000 non-null   int64
#  9   Revenue      1000 non-null   float64
#  10  Metascore    1000 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
df['Genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
df['Genre'].value_counts().head(10)
# Out:
# Genre
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Name: count, dtype: int64

# %%
df['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
len(df['Genre'].unique())
# Out:
# 207

# %% [markdown]
# #### Corr Method (Corelation)

# %%
numeric_df = df.select_dtypes(include=['number'])
corrmat = numeric_df.corr()
corrmat
# Out:
#                Year   Runtime    Rating     Votes   Revenue  Metascore
# Year       1.000000 -0.164900 -0.211219 -0.411904 -0.117562  -0.076077
# Runtime   -0.164900  1.000000  0.392214  0.407062  0.247834   0.202239
# Rating    -0.211219  0.392214  1.000000  0.511537  0.189527   0.604723
# Votes     -0.411904  0.407062  0.511537  1.000000  0.607941   0.318116
# Revenue   -0.117562  0.247834  0.189527  0.607941  1.000000   0.132304
# Metascore -0.076077  0.202239  0.604723  0.318116  0.132304   1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(corrmat, annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='scatter', x='Rating', y='Revenue', title= 'Revenue vs Rating')
# Out:
# <Axes: title={'center': 'Revenue vs Rating'}, xlabel='Rating', ylabel='Revenue'>

# %%
df['Rating'].plot(kind='hist', bins=10, title='Rating Distribution')
# Out:
# <Axes: title={'center': 'Rating Distribution'}, ylabel='Frequency'>

# %%
df['Rating'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 7.1    52
# 6.7    48
# 7.0    46
# 6.3    44
# 7.3    42
# 7.2    42
# 6.6    42
# 6.5    40
# 7.8    40
# 6.2    37
# 6.8    37
# 7.5    35
# 6.4    35
# 7.4    33
# 6.1    31
# 6.9    31
# 7.6    27
# 7.7    27
# 5.8    26
# 6.0    26
# 8.1    26
# 7.9    23
# 5.7    21
# 5.9    19
# 8.0    19
# 5.6    17
# 5.5    14
# 5.4    12
# 5.3    12
# 5.2    11
# 8.2    10
# 4.9     7
# 8.3     7
# 8.5     6
# 4.7     6
# 4.6     5
# 5.1     5
# 4.3     4
# 5.0     4
# 8.4     4
# 4.8     4
# 3.9     3
# 8.6     3
# 4.2     2
# 3.5     2
# 2.7     2
# 8.8     2
# 3.7     2
# 4.1     1
# 9.0     1
# 4.0     1
# 3.2     1
# 4.5     1
# 1.9     1
# 4.4     1
# Name: count, dtype: int64

# %%
df['Rating'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Rating'].describe()
# Out:
# count    1000.000000
# mean        6.723200
# std         0.945429
# min         1.900000
# 25%         6.200000
# 50%         6.800000
# 75%         7.400000
# max         9.000000
# Name: Rating, dtype: float64

# %%
rating_cat = []
for rate in df['Rating']:
    if rate > 6.2:
        rating_cat.append('Good')
    else:
        rating_cat.append('Bad')

# %%
rating_cat
# Out:
# ['Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Bad',
#  'Bad',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Bad',
#  'Good',
#  'Bad',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Bad',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
#  'Good',
# ...

# %%
df['Rating Category'] = rating_cat

# %%
df.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  Runtime  \
# Rank
# ...

# %%
df.boxplot(column='Revenue', by='Rating Category')
# Out:
# <Axes: title={'center': 'Revenue'}, xlabel='Rating Category'>

# %% [markdown]
# # DATETIME

# %% [markdown]
# ## Review Python's datetime module

# %%
import datetime as dt

# %%
today = dt.date(2025,2,27)

# %%
print(today)
# Out:
# 2025-02-27

# %%
print(today.day, today.month, today.year)
# Out:
# 27 2 2025

# %%
today = dt.datetime(2025,2,27,12,30,45)

# %%
print(today)
# Out:
# 2025-02-27 12:30:45

# %%
print(today.hour, today.minute, today.second)
# Out:
# 12 30 45

# %% [markdown]
# ## Timestamp

# %%
pd.Timestamp('2015-02-27')
# Out:
# Timestamp('2015-02-27 00:00:00')

# %% [markdown]
# ## DateTimeIndex

# %%
dates = ['2015-02-27', '2016-04-12', '2009-09-07']

# %%
pd.DatetimeIndex(dates)
# Out:
# DatetimeIndex(['2015-02-27', '2016-04-12', '2009-09-07'], dtype='datetime64[ns]', freq=None)

# %%
type(dates)
# Out:
# list

# %%
dates = [dt.date(2015,2,27), dt.date(2016,4,12), dt.date(2009,9,7)]

# %%
dates
# Out:
# [datetime.date(2015, 2, 27),
#  datetime.date(2016, 4, 12),
#  datetime.date(2009, 9, 7)]

# %%
dateIndex = pd.DatetimeIndex(dates)
dateIndex
# Out:
# DatetimeIndex(['2015-02-27', '2016-04-12', '2009-09-07'], dtype='datetime64[ns]', freq=None)

# %%
values = [12, 13, 10]
pd.Series(data=values, index=dateIndex)
# Out:
# 2015-02-27    12
# 2016-04-12    13
# 2009-09-07    10
# dtype: int64

# %% [markdown]
# ## pd.to_datetime()

# %%
pd.to_datetime('2025/02/27')
# Out:
# Timestamp('2025-02-27 00:00:00')

# %%
pd.to_datetime(dt.date(2025,2,27))
# Out:
# Timestamp('2025-02-27 00:00:00')

# %%
pd.to_datetime(dt.datetime(2025,2,27,12,30,45))
# Out:
# Timestamp('2025-02-27 12:30:45')

# %%
dates = ['2015-02-27', '2016-04-12', '2009-09-07']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2015-02-27', '2016-04-12', '2009-09-07'], dtype='datetime64[ns]', freq=None)

# %%
dates = pd.Series(['December 22nd, 2025', '2016-04-12', 'Colemerg', '2009,09,07', '24th Dec, 2019'])
dates
# Out:
# 0    December 22nd, 2025
# 1             2016-04-12
# 2               Colemerg
# 3             2009,09,07
# 4         24th Dec, 2019
# dtype: object

# %%
pd.to_datetime(dates, errors='coerce')
# Out:
# 0   2025-12-22
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# dtype: datetime64[ns]

# %%
unixtime = [177463, 23987234, 230982348]

# %%
pd.to_datetime(unixtime, unit='s')
# Out:
# DatetimeIndex(['1970-01-03 01:17:43', '1970-10-05 15:07:14',
#                '1977-04-27 09:45:48'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## Create Range in the form of Date `pd.date_range()`

# %%
range(1, 10, 2)
# Out:
# range(1, 10, 2)

# %%
times = pd.date_range(start='2016-01-01', end='2017-01-10', freq='D')
times
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10'],
#               dtype='datetime64[ns]', length=376, freq='D')

# %% [markdown]
# ## Import Stock Data using `datareader`

# %%
# !pip install pandas_datareader
from pandas_datareader import data
import yfinance as yf

# %%
company = "MSTF"
start = "2019-01-01"
end = "2025-2-27"

# %%
stocks = yf.download(company, start=start, end=end)
stocks
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker              MSTF          MSTF          MSTF          MSTF      MSTF
# Date
# 2022-12-14  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  10000000
# 2022-12-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06      5000
# 2023-01-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06     80000
# 2023-01-27  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  20000010
# 2023-02-17  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06    105000
# 2023-05-04  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06   1500000
# 2023-08-11  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06   3500000
# 2023-11-09  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06   2300000
# 2023-12-01  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06   1189103
# ...

# %%
stocks.loc["2022-12-14"]
# Out:
# Price   Ticker
# Close   MSTF      1.000000e-06
# High    MSTF      1.000000e-06
# Low     MSTF      1.000000e-06
# Open    MSTF      1.000000e-06
# Volume  MSTF      1.000000e+07
# Name: 2022-12-14 00:00:00, dtype: float64

# %%
stocks.loc["2022-12-14": "2023-02-17"]
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker              MSTF          MSTF          MSTF          MSTF      MSTF
# Date
# 2022-12-14  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  10000000
# 2022-12-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06      5000
# 2023-01-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06     80000
# 2023-01-27  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  20000010
# 2023-02-17  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06    105000

# %%
stocks.truncate(before="2022-12-14", after="2023-02-17")
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker              MSTF          MSTF          MSTF          MSTF      MSTF
# Date
# 2022-12-14  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  10000000
# 2022-12-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06      5000
# 2023-01-23  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06     80000
# 2023-01-27  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06  20000010
# 2023-02-17  1.000000e-06  1.000000e-06  1.000000e-06  1.000000e-06    105000

# %% [markdown]
# ## Timedelta

# %%
timeA = pd.Timestamp('2015-02-27')
timeB = pd.Timestamp('2016-04-12')#

# %%
timeB - timeA
# Out:
# Timedelta('410 days 00:00:00')

# %%
pd.Timedelta(weeks=10, days=2, hours=3, minutes=23)
# Out:
# Timedelta('72 days 03:23:00')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/ecommerce.csv',
                 index_col='ID',
                 parse_dates=['order_date', 'delivery_date'],
                 dayfirst=True)
df.head()
# Out:
# <ipython-input-209-6506aa2f7f35>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/ecommerce.csv',
# <ipython-input-209-6506aa2f7f35>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/ecommerce.csv',
#    order_date delivery_date
# ID
# 1  1998-05-24    1999-05-02
# 2  1992-04-22    1998-06-03
# 4  1991-10-02    1992-08-26
# 5  1992-07-21    1997-11-20
# 7  1993-02-09    1998-10-06

# %%
df['Delivery_Time'] = df['delivery_date'] - df['order_date']
df.head()
# Out:
#    order_date delivery_date Delivery_Time
# ID
# 1  1998-05-24    1999-05-02      343 days
# 2  1992-04-22    1998-06-03     2233 days
# 4  1991-10-02    1992-08-26      329 days
# 5  1992-07-21    1997-11-20     1948 days
# 7  1993-02-09    1998-10-06     2065 days
